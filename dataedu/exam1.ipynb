# %% [markdown]
# # 정적 웹 크롤링과 스크래핑

# %% [markdown]
# ### <span style='color:red'>urllib.request.urlopen()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print("NAVER 웹페이지의 소스 내용----------------------------------------------------------------")
print(res.read(1000).decode('utf-8'))
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# NAVER 웹페이지의 소스 내용----------------------------------------------------------------
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s

# %%
help(res.read)
# Out:
# Help on method read in module http.client:
#
# read(amt=None) method of http.client.HTTPResponse instance
#     Read and return the response body, or up to the next amt bytes.

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/get.php")
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
print(res.read()) # 바이트 문자열, 바이트열 - b'..............'
# Out:
# [ header 정보 ]----------
# ('Date', 'Wed, 17 Jun 2026 00:29:30 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '183')
# ('Connection', 'close')
# ('Content-Type', 'text/html; charset=UTF-8')
# [ body 내용 ]-----------
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <title>GET TEST</title>\n  </head>\n  <body>\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\n</html>'

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/get.php")
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
print(res.read().decode('utf-8'))
# Out:
# [ header 정보 ]----------
# ('Date', 'Wed, 17 Jun 2026 00:29:31 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '183')
# ('Connection', 'close')
# ('Content-Type', 'text/html; charset=UTF-8')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %% [markdown]
# ### urllib.parse.urlencode() 함수로 Query 문자열(요청 파라미터) 인코딩하기

# %%
import urllib
print("[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urllib.parse.urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
# Out:
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show

# %%
params2 = urllib.parse.urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib
print(urllib.parse.quote_plus('가나다 ABC123'))
query_str1 = "q="+urllib.parse.quote_plus('가나 다')
query_str2 = urllib.parse.urlencode({"q" : "가나 다"})
print("-------------------------------------------")
print(query_str1)
print(query_str2)
# Out:
# %EA%B0%80%EB%82%98%EB%8B%A4+ABC123
# -------------------------------------------
# q=%EA%B0%80%EB%82%98+%EB%8B%A4
# q=%EA%B0%80%EB%82%98+%EB%8B%A4

# %% [markdown]
# ### Query 문자열 전달하면서 GET 방식으로 요청하기

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print(f"URL 인코딩 규칙이 적용된 문자열 : {params}")
url = f"http://unico2013.dothome.co.kr/crawling/get.php?{params}"
print(f"URL 문자열 : {url}")
with urllib.request.urlopen(url) as f:#
    print(f.read().decode('utf-8'))

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(1)
# **<span style="color:red">urllib.request.urlopen() 사용</span>**

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print(f"URL 인코딩 규칙이 적용된 문자열 : {data}")
postdata = data.encode('ascii')
print(f"변환된 바이트 문자열 : {postdata}")
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, data=postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 요청 파라미터 전달하면서 POST 방식으로 요청하기(2)
# **<span style="color:red">urllib.request.Request() 와 urllib.request.urlopen() 사용</span>**

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '역사', 'age': 25})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x000001E4DBAD3530>
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
filename, header = urllib.request.urlretrieve('http://unico2013.dothome.co.kr/image/flower.jpg', "output/test1.jpg")

# %%
from PIL import Image
img = Image.open(filename) 
img.show()

# %% [markdown]
# <hr style="background-color:green; height:5px;">

# %% [markdown]
# ### <span style='color:red'>requests.request()</span> 함수로 웹페이지 소스 크롤링하기

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.head('http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.post('http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
print(r.headers)
if r.content :
    print(r.content) 
    print('-'*100)
    print(r.content.decode('utf-8'))
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 17 Jun 2026 01:10:28 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '183', 'Connection': 'close', 'Content-Type': 'text/html; charset=UTF-8'}
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <title>GET TEST</title>\n  </head>\n  <body>\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\n</html>'
# ----------------------------------------------------------------------------------------------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/get.php')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 17 Jun 2026 01:10:29 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '183', 'Connection': 'close', 'Content-Type': 'text/html; charset=UTF-8'}
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# {'Date': 'Wed, 17 Jun 2026 01:41:53 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'Content-Length': '164', 'Connection': 'close', 'Content-Type': 'text/html'}
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <title>GET TEST</title>\n  </head>\n  <body>\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\n</html>'
# ------------------------------------
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>GET TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %% [markdown]
# ### 이미지 크롤링하여 파일로 저장하기

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("output/test2.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
from PIL import Image
img = Image.open('output/test2.jpg') 
img.show()

# %% [markdown]
# ### 크롤링한 웹페이지 내용을 BeautifulSoup으로 스크래핑하기

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'bs4.element.AttributeDict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p') #여러 개를 한번에 반환해야 하니까 컬렉션 형태로 반환
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
print(bs.find('p'))
# Out:
# <p align="center"> text contents </p>

# %%
print("|", bs.find('p').text, "|", sep="")
# Out:
# | text contents |

# %%
print("|", bs.find('p').text.strip(), "|", sep="")
print("|", bs.find('p').string.strip(), "|", sep="")
# Out:
# |text contents|
# |text contents|

# %%
print("|", bs.find('p').get_text().strip(), "|", sep="")
print("|", bs.find('p').get_text(strip=True), "|", sep="")
# Out:
# |text contents|
# |text contents|

# %%
print(bs.find('p').attrs)
# Out:
# {'align': 'center'}

# %%
print(bs.find('p').get("align"))
# Out:
# center

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[[[ string 속성 ]]]")#태그 안에 문자열이 딱 1개만 있어야 함, 그 외에는 none반환
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[[[ text 속성 ]]]") #모든 텍스트 추출
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[[[ contents 속성 ]]]") #태그 안의 모든 자식 노드(태그 포함)
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
# Out:
# [[[ string 속성 ]]]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [[[ text 속성 ]]]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [[[ contents 속성 ]]]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content

bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')

print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %% [markdown]
# ### YES24 사이트에 올려져 있는 '파이썬' 관련 서적 정보 수집하기

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
search_book = 'python'
urlstr = f'https://www.yes24.com/Product/Search?domain=BOOK&query={search_book}'
r = requests.get(urlstr)
bs = BeautifulSoup(r.text, 'html.parser')
bookList = bs.select('a.gd_name')#a.gd_name선택자, gd_name이라는 속성을 갖는 a태그

for bookDom in bookList:
    title.append(bookDom.string)#책이름은 string으로 뽑아내고
    link.append(bookDom["href"])#추출된 태그 붙이기?

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '파이썬의 도구들', '혼자 공부하는 파이썬', '오렌지3 with 파이썬', 'LUVIT♥ EPL과 유튜브 데이터로 배우는 DuckDB', '2026 시나공 빅데이터분석기사 실기 Python', '요즘 바이브 코딩 커서 X 클로드 코드 실전 외주 돈 벌기', '2026 이기적 빅데이터분석기사 실기 Python', '바로바로 바이브 코딩 with 커서 AI', '밑바닥부터 시작하는 딥러닝 1', 'Black Hat Python 2/e', '파이썬 코딩의 기술 51 Better Python Code', 'Do it! 점프 투 파이썬 + Do it! LLM을 활용한 AI 에이전트 개발 입문 세트', 'Do it! LLM을 활용한 AI 에이전트 개발 입문', '파이썬Python과 언어 연구', 'Building Machine Learning Systems with Python 한국어판', '인과관계 추론과 발견 with Python', 'Python 기반 연구방법론', '데이터과학자를 위한 통계분석 STATA & Python', '핸즈온 그래프 인공신경망 with Python', '코딩 입문 PYTHON', '누구나 쉽게 배우는 Python+Django', '처음 만나는 AI 수학 with Python', '파이썬 딥러닝 파이토치 (Python Deep Learning PyTorch)']
# -- 도서 링크 URL --
# ['/product/goods/119293186', '/product/goods/191208982', '/product/goods/109625396', '/product/goods/191890082', '/product/goods/191697558', '/product/goods/185160480', '/product/goods/187024885', '/product/goods/154842828', '/product/goods/183530330', '/product/goods/141787639', '/product/goods/108802330', '/product/goods/128897247', '/product/goods/148027839', '/product/goods/146036009', '/product/goods/145654281', '/product/goods/20296766', '/product/goods/126115088', '/product/goods/154230632', '/product/goods/136298430', '/product/goods/134867624', '/product/goods/181392342', '/product/goods/151171136', '/product/goods/96805069', '/product/goods/93376077']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
query_dict = {'domain':'BOOK', 'query':'python'}
urlstr = 'https://www.yes24.com/Product/Search'
r = requests.get(urlstr, params=query_dict)
bs = BeautifulSoup(r.text, 'html.parser')
bookList = bs.select('a.gd_name')

for bookDom in bookList:
    title.append(bookDom.string)
    link.append(bookDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)

with open('output/booklink_1page.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')#가져온 정보를 booklink에 저장
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '파이썬의 도구들', '혼자 공부하는 파이썬', '오렌지3 with 파이썬', 'LUVIT♥ EPL과 유튜브 데이터로 배우는 DuckDB', '2026 시나공 빅데이터분석기사 실기 Python', '요즘 바이브 코딩 커서 X 클로드 코드 실전 외주 돈 벌기', '2026 이기적 빅데이터분석기사 실기 Python', '바로바로 바이브 코딩 with 커서 AI', '밑바닥부터 시작하는 딥러닝 1', 'Black Hat Python 2/e', '파이썬 코딩의 기술 51 Better Python Code', 'Do it! 점프 투 파이썬 + Do it! LLM을 활용한 AI 에이전트 개발 입문 세트', 'Do it! LLM을 활용한 AI 에이전트 개발 입문', '파이썬Python과 언어 연구', 'Building Machine Learning Systems with Python 한국어판', '인과관계 추론과 발견 with Python', 'Python 기반 연구방법론', '데이터과학자를 위한 통계분석 STATA & Python', '핸즈온 그래프 인공신경망 with Python', '코딩 입문 PYTHON', '누구나 쉽게 배우는 Python+Django', '처음 만나는 AI 수학 with Python', '파이썬 딥러닝 파이토치 (Python Deep Learning PyTorch)']
# -- 도서 링크 URL --
# ['/product/goods/119293186', '/product/goods/191208982', '/product/goods/109625396', '/product/goods/191890082', '/product/goods/191697558', '/product/goods/185160480', '/product/goods/187024885', '/product/goods/154842828', '/product/goods/183530330', '/product/goods/141787639', '/product/goods/108802330', '/product/goods/128897247', '/product/goods/148027839', '/product/goods/146036009', '/product/goods/145654281', '/product/goods/20296766', '/product/goods/126115088', '/product/goods/154230632', '/product/goods/136298430', '/product/goods/134867624', '/product/goods/181392342', '/product/goods/151171136', '/product/goods/96805069', '/product/goods/93376077']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'https://www.yes24.com/Product/Search?domain=BOOK&query=python&page='

for pnum in range(1, 11) :
    urlstr_pagenum = urlstr+str(pnum)
    req = requests.get(urlstr_pagenum)
    print(f'{urlstr_pagenum} 요청.....')
    bs = BeautifulSoup(req.text, 'html.parser')
    book_list = bs.select('a.gd_name')
    
    for dom in book_list:
        print(dom.string)
        title.append(dom.string)
        link.append(dom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
import pandas as pd
dictdata = {"booktitle":title,"booklink":link}
df = pd.DataFrame(dictdata)
df.to_csv("output/booklink_10page.csv")

# %% [markdown]
# ## <span style='color:blue; font-weight:bold'>파이썬을 사용한 웹 페이지의 정적 수집 방법에 대하여 학습했습니다.</span>
