# %% [markdown]
# # **<span style="color:red">동적 웹 크롤링과 스크래핑</span>**

# %% [markdown]
# ## selenium API 설치

# %% [markdown]
# ![image.png](attachment:db47bba9-4711-47a6-a961-2c83a663bb0a.png)

# %%
pip show selenium
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: selenium

# %%
# selenium API 를 (재)설치 합시다요~~~~~
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.45.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting certifi>=2026.2.25 (from selenium)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\user\anaconda3\lib\site-packages (from selenium) (4.15.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\user\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.45.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------- ----- 8.1/9.5 MB 41.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 37.3 MB/s  0:00:00
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, outcome, certifi, trio, trio-websocket, selenium
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.5.0
#
#     Uninstalling urllib3-2.5.0:
#
#       Successfully uninstalled urllib3-2.5.0
#
#   Attempting uninstall: certifi
#
#     Found existing installation: certifi 2025.11.12
#
#     Uninstalling certifi-2025.11.12:
#
#       Successfully uninstalled certifi-2025.11.12
#
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed certifi-2026.6.17 outcome-1.3.0.post0 selenium-4.45.0 trio-0.33.0 trio-websocket-0.12.2 urllib3-2.7.0 wsproto-1.3.2

# %% [markdown]
# ![image.png](attachment:fe4b594d-e860-4ac6-b360-c1deaab5442e.png)

# %%
pip show selenium
# Out:
# Name: selenium
# Version: 4.45.0
# Summary: Official Python bindings for Selenium WebDriver
# Home-page: https://www.selenium.dev
# Author:
# Author-email:
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, trio, trio-websocket, typing_extensions, urllib3, websocket-client
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Selenium(셀레늄)
# - 웹 브라우저의 동작을 자동화하는 데 가장 널리 사용되는 오픈소스 프레임워크입니다.
# - 사람이 직접 브라우저에서 클릭하고, 타이핑하고, 스크롤하는 모든 행위를 파이썬 코드로 대신 수행하게 만들 수 있습니다.
# - 크롤링뿐만 아니라 웹 서비스가 정상적으로 작동하는지 테스트하는 자동화 도구로도 필수적인 역할을 합니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome() # selnium 4.16 부터
print("WebDriver 객체 : ", type(driver))
# Out:
# WebDriver 객체 :  <class 'selenium.webdriver.chrome.webdriver.WebDriver'>

# %%
driver.get('https://www.naver.com/')#네이버창 불러오기

# %%
target=driver.find_element(By.CSS_SELECTOR, "[name = 'query']")
target.send_keys('둘리')#입력창에 둘리 입력
#추가로 이걸 또 입력할 경우, 입력창 
#둘리 뒤에 둘리가 하나 더 붙음

# %%
target.send_keys(Keys.ENTER)#엔터키 입력하기

# %%
driver.get('https://www.naver.com/')
target=driver.find_element(By.ID, "query")
target.send_keys('또치')
target.send_keys(Keys.ENTER)

# %%
driver.get('https://www.naver.com/')
target=driver.find_element(By.CLASS_NAME, "search_input")
target.send_keys('도우너')
target.send_keys(Keys.ENTER)

# %%
driver.quit()

# %% [markdown]
# ### 네이버 검색 창에 일반 텍스트 입력하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get("http://www.naver.com")

# 검색어 입력 필드 찾기
input_element = driver.find_element(By.ID, 'query')

# 텍스트 입력
input_element.send_keys('서울 날씨')

# %% [markdown]
# ### 입력한 텍스트로 검색 진행하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

driver.get("http://www.naver.com")

# 검색어 입력 필드 찾기
input_element = driver.find_element(By.ID, 'query')

# 텍스트 입력
input_element.send_keys('서울 날씨')
input_element.submit()

# 엔터키 입력
target.send_keys(Keys.ENTER)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[18], line 16
#      13 input_element.submit()
#      15 # 엔터키 입력
# ---> 16 target.send_keys(Keys.ENTER)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:276, in WebElement.send_keys(self, *value)
#     273             remote_files.append(self._upload(file))
#     274         value = tuple("\n".join(remote_files))
# --> 276 self._execute(
#     277     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     278 )
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:492, in WebDriver.execute(self, driver_command, params)
#     489 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     491 if response:
# --> 492     self.error_handler.check_response(response)
#     493     response["value"] = self._unwrap_value(response.get("value", None))
#     494     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=149.0.7827.103); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff7094f3fa5+14925]
# 	chromedriver!GetHandleVerifier [0x7ff7094f4000+14980]
# 	chromedriver!(No symbol) [0x7ff70903793d]
# 	chromedriver!(No symbol) [0x7ff70904f63d]
# 	chromedriver!(No symbol) [0x7ff70904dd40]
# 	chromedriver!(No symbol) [0x7ff70904050b]
# 	chromedriver!(No symbol) [0x7ff70903e30e]
# 	chromedriver!(No symbol) [0x7ff709042875]
# 	chromedriver!(No symbol) [0x7ff70904293f]
# 	chromedriver!(No symbol) [0x7ff709092b80]
# 	chromedriver!(No symbol) [0x7ff709092c77]
# 	chromedriver!(No symbol) [0x7ff70908988a]
# 	chromedriver!(No symbol) [0x7ff7090ba3ca]
# 	chromedriver!(No symbol) [0x7ff7090857c6]
# 	chromedriver!(No symbol) [0x7ff7090df39b]
# 	chromedriver!(No symbol) [0x7ff70908401c]
# 	chromedriver!(No symbol) [0x7ff709084f43]
# 	chromedriver!GetHandleVerifier [0x7ff709ad7591+5f7f11]
# 	chromedriver!GetHandleVerifier [0x7ff709ad1902+5f2282]
# 	chromedriver!GetHandleVerifier [0x7ff709af7115+617a95]
# 	chromedriver!GetHandleVerifier [0x7ff709511dce+3274e]
# 	chromedriver!GetHandleVerifier [0x7ff70951a82c+3b1ac]
# 	chromedriver!GetHandleVerifier [0x7ff7094fd744+1e0c4]
# 	chromedriver!GetHandleVerifier [0x7ff7094fd8d4+1e254]
# 	chromedriver!GetHandleVerifier [0x7ff7094e1447+1dc7]
# 	KERNEL32!BaseThreadInitThunk [0x7ffcf47ee957+17]
# 	ntdll!RtlUserThreadStart [0x7ffcf55a7c1c+2c]

# %% [markdown]
# ### 특수 키 사용하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()
driver.get("http://www.naver.com")

# 검색어 입력 필드 찾기
input_element = driver.find_element(By.ID, 'query')

# 텍스트 입력
input_element.send_keys('서울 날씨')
input_element.send_keys(Keys.ENTER)

# %% [markdown]
# ### 파이썬에서 입력 받은 값으로 검색하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()
driver.get("http://www.naver.com")

# 사용자로부터 검색할 단어를 입력받기
search_query = input('검색할 단어를 입력하세요: ')

# 검색어 입력 필드 찾기
input_element = driver.find_element(By.ID, 'query')

# 검색창에 사용자가 입력한 검색어를 입력
input_element.send_keys(search_query)

# ENTER 키를 눌러 검색 실행
input_element.send_keys(Keys.ENTER)

# %% [markdown]
# ### 마우스 클릭하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Chrome()
driver.get('http://www.naver.com')

# 이미지 검색 페이지 버튼 찾기
element_to_click = driver.find_element(By.CSS_SELECTOR, '#shortcutArea > ul > li:nth-child(3) > a > span.service_icon.type_blog')
# 마우스 클릭 실행
element_to_click.click()

# %% [markdown]
# ### 스크롤바 이동하기

# %%
from selenium import webdriver
#정말 원하는 정보를 크롤링하려면, 스크롤바 내리기도 필요함. 
#그 창에 들어간다고 정보가 다 가져와 지는게 아님
#ajax에서 스크롤를 해야 댓글 정보를 가져오는 코드를 짜서 그런가?
driver = webdriver.Chrome()
driver.get('https://www.naver.com')

# y축 방향으로 500 픽셀만큼 이동
driver.execute_script('window.scrollTo(0, 500)')

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('https://www.naver.com')

# 페이지 최하단으로 스크롤
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')

# %% [markdown]
# ### 특정 요소 위치로 스크롤바 이동하기

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('https://www.naver.com')

# 페이지에서 [증시] 코너의 [증시] 요소 찾기
element = driver.find_element(By.PARTIAL_LINK_TEXT, '증시')
element = driver.find_element(By.PARTIAL_LINK_TEXT, '증시')

# 해당 요소가 화면 중앙으로 오도록 부드럽게 스크롤바를 조정
driver.execute_script("arguments[0].scrollIntoView({behavior: 'smooth', block: 'center', inline: 'center'});", element)

# %% [markdown]
# ### 스크린샷하기

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome()
driver.get('https://www.google.com')

driver.save_screenshot('output/full_page_screenshot.png')
time.sleep(3)
driver.quit()

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('https://www.google.com')

# 구글 메인 로고 요소 찾아 캡처
element = driver.find_element(By.CSS_SELECTOR, '#LS8OJ > div > svg')
element.screenshot('output/element_screenshot.png')
driver.quit()

# %% [markdown]
# ### 웹 브라우저를 띄우지 않고 자동화하기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# 옵션 객체 생성
options = webdriver.ChromeOptions() 
options.add_argument("--headless") # 헤드리스 모드 활성화
#브라우저를 화면에 띄우지 않고 데이터 수집? 메?

# 설정된 옵션을 포함하여 웹 드라이버 인스턴스 생성
driver = webdriver.Chrome(options=options)
driver.get('https://www.google.com')

# 구글 메인 로고 요소 찾아 캡처
element = driver.find_element(By.CSS_SELECTOR, '#hplogo')
element.screenshot('output/element_screenshot_headlessmode.png')

driver.quit()

# %% [markdown]
# #### 스타벅스의 매장 정보를 볼 수 있는 사이트 입니다.
# ##### https://www.istarbucks.co.kr/store/store_map.do

# %%
import urllib.request
from bs4 import BeautifulSoup
#서버 접속
server = urllib.request.urlopen("https://www.istarbucks.co.kr/store/store_map.do")

response =server.read().decode()
bs = BeautifulSoup(response, "html.parser")
li = bs.find_all('li', class_="quickResultLstCon")
print(li)
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get("https://www.istarbucks.co.kr/store/store_map.do")

# %%
target=driver.find_element(By.CLASS_NAME, "quickResultLstCon")

print(type(target))
print(type(target.text))
print(target.text)
#driver.quit()

# %%
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
print('-----------------------------')
byTagName = driver.find_element(By.TAG_NAME,'h1')#조건에 맞는 첫번째 요소만 리턴
print(type(byTagName))
print(byTagName.tag_name, ":", byTagName.text)
print('-----------------------------')
byTagNames = driver.find_elements(By.TAG_NAME, 'h2')#조건에 맞는 요소를 다 출력함
print(type(byTagNames))
for tagName in byTagNames :
   print(tagName.tag_name, ":", tagName.text)
# Out:
# -----------------------------
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# h1 : CSS 선택자 학습
# -----------------------------
# <class 'list'>
# h2 : 교육과정 소개
# h2 : 웹 클라이언트 기술
# h2 : 학습 순서(수집)

# %%
byClassName = driver.find_element(By.CLASS_NAME,'subtitle')
print(type(byClassName))#웹 클라이언트 기술
print(byClassName.tag_name, ":", byClassName.text)#h2:웹 클라이언트 기술
print('-----------------------------')
byClassNames = driver.find_elements(By.CLASS_NAME, 'subtitle')
print(type(byClassNames))
for className in byClassNames :
   print(className.tag_name, ":", className.text)#h2 : 웹 클라이언트 기술
#h2 : 학습 순서(수집)
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# h2 : 웹 클라이언트 기술
# -----------------------------
# <class 'list'>
# h2 : 웹 클라이언트 기술
# h2 : 학습 순서(수집)

# %%
byId = driver.find_element(By.ID,'btype')
print(type(byId))
print(byId.tag_name, ":", byId.text)
print('-----------------------------')
byLinkText = driver.find_element(By.LINK_TEXT,'파이썬 학습 사이트')
print(type(byLinkText))
print(byLinkText.tag_name, ":", byLinkText.text)
print('-----------------------------')
byPLinkText = driver.find_elements(By.PARTIAL_LINK_TEXT,'사이트')
print(type(byPLinkText))
for linkText in byPLinkText :
   print(linkText.tag_name, ":", linkText.text)
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# li : HTML5
# -----------------------------
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# a : 파이썬 학습 사이트
# -----------------------------
# <class 'list'>
# a : HTML, CSS, JavaScript 학습 사이트
# a : 파이썬 학습 사이트

# %%
byCss1 = driver.find_element(By.CSS_SELECTOR, 'section>h2')
print(type(byCss1))
print(byCss1.tag_name, ":", byCss1.text)
print('-----------------------------')
byCss2 = driver.find_element(By.CSS_SELECTOR,'aside>h2')
print(type(byCss2))
print(byCss2.tag_name, ":", byCss2.text)
print('-----------------------------')
byCss3 = driver.find_element(By.CSS_SELECTOR,'body > section > article > ul > li:nth-child(3)')
print(type(byCss3))
print(byCss3.tag_name, ":", byCss3.text)
print('-----------------------------')
byCss4 = driver.find_elements(By.CSS_SELECTOR,'ul>li.atype')
print(type(byCss4))
for byCss in byCss4 :
   print(byCss.tag_name, ":", byCss.text)

# %%
byXpath1 = driver.find_element(By.XPATH,'//*[@id="f_subtitle"]')
print(type(byXpath1))
print(byXpath1.tag_name, ":", byXpath1.text)
print('-----------------------------')
byXpath2 = driver.find_element(By.XPATH,'/html/body/section/article/ul/li[3]')
print(type(byXpath2))
print(byXpath2.tag_name, ":", byXpath2.text)
print('-----------------------------')
byXpath3 = driver.find_elements(By.XPATH,'//ul/li[@class="atype"]')
print(type(byXpath3))
for byXpath in byXpath3 :
   print(byXpath.tag_name, ":", byXpath.text)

# %%
byXpath1 = driver.find_element(By.XPATH,'//div/img')
print(type(byXpath1))
print(byXpath1.tag_name, ":", byXpath1.get_attribute('src'))
print('-----------------------------')
byXpath2 = driver.find_elements(By.XPATH,'/html/body/header/nav/a')
print(type(byXpath2))
for byXpath in byXpath2 :
   print(byXpath.tag_name, ":", byXpath.get_attribute('href'))

# %%
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

url = "https://www.megabox.co.kr/movie-detail/comment?rpstMovieNo=21033000"
#페이지네이션을 하고 클릭했는데, url이 변경 안된다면,
#그건 자바스크립트로 작성했다는 의미
driver =  webdriver.Chrome()
driver.get(url)

points = list()
recommends = list()
txts = list()

# 1페이지 정보
time.sleep(2)
points.extend([p.text for p in driver.find_elements(By.CLASS_NAME, 'story-point')])
recommends.extend([r.text for r in driver.find_elements(By.CLASS_NAME,'story-recommend')])
txts.extend([t.text for t in driver.find_elements(By.CLASS_NAME,'story-txt')])

# 2~30 페이지 정보
for page in range(2, 31):
    if page % 10 == 1:
        next_btn = driver.find_element(By.CSS_SELECTOR, "#contentData > div > div.movie-idv-story > nav > a.control.next")
        next_btn.click()
    else:
        page_btn = driver.find_element(By.LINK_TEXT, str(page))#LINK_TEXT 찾아옴
        page_btn.click()#클릭하고 페이지 이동 이때 잠시 시간이 지남
    #driver.implicitly_wait(3)
    time.sleep(2)#잠시 시간 지나는 걸 대기시간 걸어둬야 됨
    
    points.extend([p.text for p in driver.find_elements(By.CLASS_NAME,'story-point')])
    recommends.extend([r.text for r in driver.find_elements(By.CLASS_NAME,'story-recommend')])
    txts.extend([t.text for t in driver.find_elements(By.CLASS_NAME,'story-txt')])
    
print("수집완료~~~")

with open('output/movie.csv', "wt", encoding="utf-8") as f:
    f.write("score,genre,review\n")
    for p, r, t in zip(points, recommends, txts):
        t = '"' + t.replace('"', '""') + '"'
        f.write(",".join([p, r, t])+"\n")   
#페이지네이션 링크를 가져와서 클릭 넣어주면 됨?

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get("https://www.yes24.com/Product/Goods/30666296")
import time
temp_list = []
time.sleep(3)
stopFlag = False

driver.execute_script("window.scrollTo(0, 2000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 4000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 6000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 8000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 10000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 12000);");
time.sleep(2)
driver.execute_script("window.scrollTo(0, 14000);");
total = driver.find_element(By.CSS_SELECTOR, '#total > a')
time.sleep(2)
driver.execute_script("arguments[0].click();", total)
#자바스크립트 코드로 클릭이벤트 날림
time.sleep(2)

while True :
  for n in range(4, 6) :   
    print(n) #너무 많은 a태그가 있
      
      어서, 두번째 페이지부터 css편집자를 가져와서 보니 4부터 시작하는 걸 확인함
      #그래서 4부터 크롤링하도록 함
    readLinks = driver.find_elements(By.CSS_SELECTOR, '#infoset_reviewContentList    div.reviewInfoBot.crop > a > div > span')
    for readlink in readLinks :
      #readlink.click()
      driver.execute_script("arguments[0].click();", readlink)
      time.sleep(2)
    
    reviewList = driver.find_elements(By.CSS_SELECTOR, '#infoset_reviewContentList div.reviewInfoBot.origin div.review_cont')
    time.sleep(2)

    for review in reviewList :    
      temp_list.append(review.text)
    
    if len(reviewList) < 5:
      stopFlag = True
      break
        
    if stopFlag == True :
      break
    
    linkurl = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'    
    linkNum = driver.find_element(By.CSS_SELECTOR, linkurl)
    linkNum.click()   
    time.sleep(2)
        
  dimDom = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a.bgYUI.dim' 
  try :
    driver.find_element(By.CSS_SELECTOR, dimDom)
    break
  except :
    nextPage = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a.bgYUI.next'
  linkNum = driver.find_element(By.CSS_SELECTOR, nextPage)  
  linkNum.click()
  time.sleep(2)

print("크롤링 완료~~~~")
wfile = open("output/yes24file.txt","w", encoding="utf-8") 
wfile.writelines(temp_list) 
wfile.close()
time.sleep(10)
#driver.quit()
# Out:
# 4
# 5
# 4
# 5
# 4
# 5
# 4
# 크롤링 완료~~~~

# %% [markdown]
# ### 로또 번호 수집

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.megamillions.com/')
time.sleep(2)
target=driver.find_elements(By.CSS_SELECTOR, ".numbers>.ball")
print("[Winning Numbers]")
for ball in target :
   print(ball.text)
#driver.quit()

# %% [markdown]
# ### <span style='color:blue; font-weight:bold'>동적 웹페이지 수집에 대해 학습했습니다.</span>
